# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ### Load data

# %%
target = new_client.target
target_query = target.search('coronavirus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
# 5                                                 []
# 6  [{'xref_id': 'P0C6U8', 'xref_name': None, 'xre...
# 7                                                 []
# 8  [{'xref_id': 'P0C6X7', 'xref_name': None, 'xre...
# 9                                                 []
#
#                                             organism  \
# 0                                        Coronavirus
# 1                                 Feline coronavirus
# 2                                 Murine coronavirus
# 3                                 Canine coronavirus
# 4                             Human coronavirus 229E
# 5                             Human coronavirus OC43
# ...

# %%
select_target = targets.target_chembl_id[6]
select_target
# Out:
# 'CHEMBL3927'

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=select_target).filter(standard_type="IC50")
res
# Out:
# [{'action_type': None, 'activity_comment': None, 'activity_id': 1480935, 'activity_properties': [], 'assay_chembl_id': 'CHEMBL829584', 'assay_description': 'In vitro inhibitory concentration against SARS coronavirus main protease (SARS CoV 3C-like protease)', 'assay_type': 'B', 'assay_variant_accession': None, 'assay_variant_mutation': None, 'bao_endpoint': 'BAO_0000190', 'bao_format': 'BAO_0000357', 'bao_label': 'single protein format', 'canonical_smiles': 'Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21', 'data_validity_comment': None, 'data_validity_description': None, 'document_chembl_id': 'CHEMBL1139624', 'document_journal': 'Bioorg Med Chem Lett', 'document_year': 2005, 'ligand_efficiency': {'bei': '18.28', 'le': '0.33', 'lle': '3.25', 'sei': '5.90'}, 'molecule_chembl_id': 'CHEMBL187579', 'molecule_pref_name': None, 'parent_molecule_chembl_id': 'CHEMBL187579', 'pchembl_value': '5.14', 'potential_duplicate': 0, 'qudt_units': 'http://www.openphacts.org/units/Nanomolar', 'record_id': 38410
# ...

# %%
df = pd.DataFrame.from_dict(res)
df
# Out:
#     action_type activity_comment  activity_id activity_properties  \
# 0          None             None      1480935                  []
# 1          None             None      1480936                  []
# 2          None             None      1481061                  []
# 3          None             None      1481065                  []
# 4          None             None      1481066                  []
# ..          ...              ...          ...                 ...
# 128        None             None     12041507                  []
# 129        None             None     12041508                  []
# 130        None             None     12041509                  []
# 131        None             None     12041510                  []
# 132        None             None     12041511                  []
#
#     assay_chembl_id                                  assay_description  \
# 0      CHEMBL829584  In vitro inhibitory concentration against SARS...
# ...

# %%
df.to_csv('./data/coronavirus.csv', index=False)

# %% [markdown]
# ### Pre-processing data

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#     action_type activity_comment  activity_id activity_properties  \
# 0          None             None      1480935                  []
# 1          None             None      1480936                  []
# 2          None             None      1481061                  []
# 3          None             None      1481065                  []
# 4          None             None      1481066                  []
# ..          ...              ...          ...                 ...
# 128        None             None     12041507                  []
# 129        None             None     12041508                  []
# 130        None             None     12041509                  []
# 131        None             None     12041510                  []
# 132        None             None     12041511                  []
#
#     assay_chembl_id                                  assay_description  \
# 0      CHEMBL829584  In vitro inhibitory concentration against SARS...
# ...

# %%
# Labelling
bioactivity_class = []
for i in df2.standard_value:
    if float(i) >= 10000:
        bioactivity_class.append("inactive")
    elif float(i) <= 1000:
        bioactivity_class.append("active")
    else:
        bioactivity_class.append("intermediate")

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]
df3 = pd.concat([df3, pd.Series(bioactivity_class)], axis=1).rename(columns={0: 'bioactivity_class'})

# %%
df3.to_csv('./data/bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### Calculate Lipinski

# %% [markdown]
# The Lipinski's Rule stated the following:
#
# - MW < 500 Dalton
# - Octanol-water partition coefficient (LogP) < 5
# - H-bond donors < 5
# - H-bond acceptors > 10

# %%
import numpy as np
from rdkit import Chem
from rdkit.Chem import Descriptors, Lipinski

# %%
# Claculate descriptors function
def lipinski(smiles, verbose=False):

    moldata= []
    for elem in smiles:
        mol = Chem.MolFromSmiles(elem) 
        moldata.append(mol)

    base_data= np.arange(1,1)
    i = 0
    for mol in moldata:

        desc_MolWt = Descriptors.MolWt(mol)
        desc_MolLogP = Descriptors.MolLogP(mol)
        desc_NumHDonors = Lipinski.NumHDonors(mol)
        desc_NumHAcceptors = Lipinski.NumHAcceptors(mol)

        row = np.array([desc_MolWt,
                        desc_MolLogP,
                        desc_NumHDonors,
                        desc_NumHAcceptors])

        if(i == 0):
            base_data = row
        else:
            base_data = np.vstack([base_data, row])
        i += 1

    column_names = ["MW", "LogP", "NumHDonors", "NumHAcceptors"]
    descriptors = pd.DataFrame(data=base_data, columns=column_names)

    return descriptors

# %%
df_lipinski = lipinski(df3.canonical_smiles)
df_lipinski
# Out:
#           MW     LogP  NumHDonors  NumHAcceptors
# 0    281.271  1.89262         0.0            5.0
# 1    415.589  3.81320         0.0            2.0
# 2    421.190  2.66050         0.0            4.0
# 3    293.347  3.63080         0.0            3.0
# 4    338.344  3.53900         0.0            5.0
# ..       ...      ...         ...            ...
# 128  338.359  3.40102         0.0            5.0
# 129  296.366  3.44330         0.0            3.0
# 130  276.291  4.09564         0.0            3.0
# 131  278.307  3.29102         0.0            3.0
# 132  282.383  4.10530         0.0            2.0
#
# [133 rows x 4 columns]

# %%
# Combine df_lipinski and df3
df_combined = pd.concat([df3, df_lipinski], axis=1)
df_combined
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 128      CHEMBL2146517  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...
# 129       CHEMBL187460        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C
# 130       CHEMBL363535             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 131       CHEMBL227075      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 132        CHEMBL45830             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
#
#     standard_value bioactivity_class       MW     LogP  NumHDonors  \
# ...

# %% [markdown]
# ### Convert IC50 to pIC50

# %% [markdown]
# Apply a negative logarithimic transformation (-log10) to standardise distribution

# %%
def pIC50(input):
    pIC50 = []

    for i in input['standard_value']:
        molar = i * (10**-9) # Converts nM to M
        pIC50.append(-np.log10(molar))

    input['pIC50'] = pIC50
    x = input.drop(columns=['standard_value'])
        
    return x

# %%
df_combined['standard_value'].describe()
# Out:
# count         133
# unique         93
# top       15000.0
# freq            5
# Name: standard_value, dtype: object

# %%
df_combined['standard_value'] = df_combined['standard_value'].astype('float')
df_combined['standard_value'].describe()
# Out:
# count        133.000000
# mean       85967.130075
# std       158897.319181
# min           50.000000
# 25%        10100.000000
# 50%        17500.000000
# 75%        70000.000000
# max      1000000.000000
# Name: standard_value, dtype: float64

# %%
df_final = pIC50(df_combined)
df_final
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 128      CHEMBL2146517  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...
# 129       CHEMBL187460        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C
# 130       CHEMBL363535             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 131       CHEMBL227075      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 132        CHEMBL45830             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
#
#     bioactivity_class       MW     LogP  NumHDonors  NumHAcceptors     pIC50
# ...

# %%
df_final.pIC50.describe()
# Out:
# count    133.000000
# mean       4.718269
# std        0.920910
# min        3.000000
# 25%        4.154902
# 50%        4.756962
# 75%        4.995679
# max        7.301030
# Name: pIC50, dtype: float64

# %% [markdown]
# ### Remove 'intermediate' bioactivity class

# %%
df_2class = df_final[df_final['bioactivity_class'] != 'intermediate']
df_2class
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 5         CHEMBL365134            O=C1C(=O)N(Cc2cc3ccccc3s2)c2c(Br)cccc21
# 7         CHEMBL190743             O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccc(I)cc21
# 8         CHEMBL365469            O=C1C(=O)N(Cc2cc3ccccc3s2)c2cccc(Cl)c21
# ..                 ...                                                ...
# 128      CHEMBL2146517  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...
# 129       CHEMBL187460        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C
# 130       CHEMBL363535             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 131       CHEMBL227075      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 132        CHEMBL45830             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
#
#     bioactivity_class       MW     LogP  NumHDonors  NumHAcceptors     pIC50
# ...

# %% [markdown]
# ### EDA via Lipinski's Rule

# %%
import seaborn as sns
sns.set(style='ticks')
import matplotlib.pyplot as plt

# %%
# Plot 2 bioactivity classes
plt.figure(figsize=(5,5))

sns.countplot(x='bioactivity_class', data=df_2class, edgecolor='black')

plt.xlabel('Bioactivity class', fontsize=16, fontweight='bold')
plt.ylabel('Frequency', fontsize=16, fontweight='bold')

plt.savefig('./data/plot_bioactivity_class.pdf')

# %%
# Scatter plot MW and LogP
plt.figure(figsize=(5,5))

sns.scatterplot(x='MW', y='LogP', data=df_2class, hue='bioactivity_class', size='pIC50', edgecolor='black', alpha=0.7)

plt.xlabel('MW', fontsize=16, fontweight='bold')
plt.ylabel('LogP', fontsize=16, fontweight='bold')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0)
plt.savefig('./data/plot_MW_vs_LogP.pdf')

# %% [markdown]
# Statistical analysis | Mann-Whitney U Test

# %%
def manwhitney (desciptor, verbose=False):

    from numpy.random import seed
    from numpy.random import randn
    from scipy.stats import mannwhitneyu

    seed(1)

    selection = [desciptor, 'bioactivity_class']
    df = df_2class[selection]
    active = df[df['bioactivity_class'] == 'active']
    active = active[desciptor]

    selection = [desciptor, 'bioactivity_class']
    df = df_2class[selection]
    inactive = df[df['bioactivity_class'] == 'inactive']
    inactive = inactive[desciptor]

    # Compare samples
    stat, p = mannwhitneyu(active, inactive)
    # print('Statistics=%.3f, p=%.3f' % (stat, p))

    # Interpret
    alpha = 0.05
    if p > alpha:
        interpretation = 'Same distribution (fail to reject H0)'
    else:
        interpretation = 'Different distribution (reject H0)'

    results = pd.DataFrame({'Descriptor': desciptor,
                           'Statistics': stat,
                           'p': p,
                           'alpha': alpha,
                           'Interpretation': interpretation}, index=[0])

    filename = 'mannwhitneyu_' + desciptor + '.csv'

    results.to_csv('./data/' + filename)

    if verbose:
        print(filename)
        print(results)
    else:
        return results

# %%
# Boxplots
# Create subplots
fig, axes = plt.subplots(2, 3, figsize=(15,8))

# Flatten axes for easier iteration
axes = axes.flatten()

# Iterate over columns and plot boxplots
for i, column in enumerate(df_2class.columns[3:]):
    sns.boxplot(x='bioactivity_class', y=column, data=df_2class, ax=axes[i])
    plt.xlabel('Bioactivity class', fontsize=16, fontweight='bold')
    plt.ylabel(column, fontsize=16, fontweight='bold')

# Hide the last subplot
axes[-1].axis('off')

# Save the figure to a PDF file
plt.savefig('./data/Boxplots.pdf')

plt.tight_layout()
plt.show()

# %%
pd.concat([manwhitney('MW'), 
           manwhitney('LogP'), 
           manwhitney('NumHDonors'), 
           manwhitney('NumHAcceptors'), 
           manwhitney('pIC50')], axis=0, ignore_index=True)
# Out:
#       Descriptor  Statistics             p  alpha  \
# 0             MW       408.5  3.313284e-03   0.05
# 1           LogP       712.5  6.306832e-01   0.05
# 2     NumHDonors       298.5  5.289419e-05   0.05
# 3  NumHAcceptors       414.0  3.402402e-03   0.05
# 4          pIC50      1545.0  4.428384e-10   0.05
#
#                           Interpretation
# 0     Different distribution (reject H0)
# 1  Same distribution (fail to reject H0)
# 2     Different distribution (reject H0)
# 3     Different distribution (reject H0)
# 4     Different distribution (reject H0)

# %% [markdown]
# ### Interpretation of Statistical Results

# %% [markdown]
# **Boxplots**
#
# **pIC50 values**
#
# Taking a look at pIC50 values, the **active** and **inactive** displayed ***statistically significant different***, which is to be expected since threshold values (IC50 < 1,000 nM = Active while IC50 > 10,000 nM = Inactives, corresponding to pIC50 > 6 = Actives and pIC50 < 5 = Inactives) were used to define actives and inactives.
#
# **Lipinski's descriptors**
#
# Of the 4 Lipinski's descriptors (MW, LopgP, NumHDonors and NumHAcceptors), only LogP exhibited ***no difference*** between the **actives** and **inactives** while the other 3 descriptors (MW, NumHDonors and NumHAcceptors) shows ***statistically significant difference*** between **actives** and **inactives**.
